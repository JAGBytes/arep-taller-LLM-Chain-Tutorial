# %%
# %pip install langchain langchain-openai langchain-core
# %pip install -U langchain langchain-openai
# Out:
# Requirement already satisfied: langchain in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (1.0.3)
# Requirement already satisfied: langchain-openai in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (1.0.2)
# Requirement already satisfied: langchain-core in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (1.0.3)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.0.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-openai) (2.7.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core) (0.4.41)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.11.1)
# Requirement already satisfied: sniffio in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: idna>=2.8 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.109.1->langchain-openai) (3.11)
# Requirement already satisfied: certifi in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: colorama in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: langchain in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (1.0.3)
# Requirement already satisfied: langchain-openai in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (1.0.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.0.3)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.0.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-openai) (2.7.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (0.4.41)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (4.15.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.11.1)
# Requirement already satisfied: sniffio in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.32.5)
# Requirement already satisfied: idna>=2.8 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.109.1->langchain-openai) (3.11)
# Requirement already satisfied: certifi in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain-openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.5.0)
# Requirement already satisfied: colorama in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip show langchain
# Out:
# Name: langchain
# Version: 1.0.3
# Summary: Building applications with LLMs through composability
# Home-page:
# Author:
# Author-email:
# License: MIT
# Location: c:\Users\jgamb\AppData\Local\Programs\Python\Python311\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "Translate the user message into {language}."),
        ("user", "{text}")
    ]
)

model = ChatOpenAI(model="gpt-4o-mini")

parser = StrOutputParser()

chain = prompt | model | parser

response = chain.invoke({
    "language": "italian",
    "text": "Hello! How are you?"
})

print("Result:", response)
# Out:
# Result: Ciao! Come stai?

# %%
# %pip install langserve fastapi uvicorn
# Out:
# Collecting langserve
#   Downloading langserve-0.3.3-py3-none-any.whl.metadata (40 kB)
#      ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#      ---------- ----------------------------- 10.2/40.3 kB ? eta -:--:--
#      ---------------------------- --------- 30.7/40.3 kB 262.6 kB/s eta 0:00:01
#      ---------------------------- --------- 30.7/40.3 kB 262.6 kB/s eta 0:00:01
#      -------------------------------------- 40.3/40.3 kB 240.4 kB/s eta 0:00:00
# Collecting fastapi
#   Downloading fastapi-0.121.0-py3-none-any.whl.metadata (28 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1.0,>=0.23.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langserve) (0.28.1)
# Requirement already satisfied: langchain-core<2,>=0.3 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langserve) (1.0.3)
# Requirement already satisfied: orjson<4,>=2 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langserve) (3.11.4)
# Requirement already satisfied: pydantic<3.0,>=2.7 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langserve) (2.12.4)
# Collecting starlette<0.50.0,>=0.40.0 (from fastapi)
#   Downloading starlette-0.49.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from fastapi) (4.15.0)
# Collecting annotated-doc>=0.0.2 (from fastapi)
#   Downloading annotated_doc-0.0.3-py3-none-any.whl.metadata (6.6 kB)
# Collecting click>=7.0 (from uvicorn)
#   Downloading click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: h11>=0.8 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: colorama in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: anyio in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from httpx<1.0,>=0.23.0->langserve) (4.11.0)
# Requirement already satisfied: certifi in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from httpx<1.0,>=0.23.0->langserve) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from httpx<1.0,>=0.23.0->langserve) (1.0.9)
# Requirement already satisfied: idna in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from httpx<1.0,>=0.23.0->langserve) (3.11)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2,>=0.3->langserve) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2,>=0.3->langserve) (0.4.41)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2,>=0.3->langserve) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2,>=0.3->langserve) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2,>=0.3->langserve) (9.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0,>=2.7->langserve) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0,>=2.7->langserve) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0,>=2.7->langserve) (0.4.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from anyio->httpx<1.0,>=0.23.0->langserve) (1.3.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=0.3->langserve) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jgamb\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve) (2.5.0)
# Downloading langserve-0.3.3-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.1/1.2 MB 5.1 MB/s eta 0:00:01
#    ------ --------------------------------- 0.2/1.2 MB 2.8 MB/s eta 0:00:01
#    -------- ------------------------------- 0.3/1.2 MB 2.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.3/1.2 MB 2.2 MB/s eta 0:00:01
#    --------------- ------------------------ 0.5/1.2 MB 2.3 MB/s eta 0:00:01
#    ------------------ --------------------- 0.6/1.2 MB 2.2 MB/s eta 0:00:01
#    --------------------- ------------------ 0.6/1.2 MB 2.2 MB/s eta 0:00:01
#    ------------------------ --------------- 0.7/1.2 MB 2.1 MB/s eta 0:00:01
#    --------------------------- ------------ 0.8/1.2 MB 2.1 MB/s eta 0:00:01
#    ------------------------------- -------- 0.9/1.2 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.0/1.2 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 1.1/1.2 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 2.0 MB/s eta 0:00:00
# Downloading fastapi-0.121.0-py3-none-any.whl (109 kB)
#    ---------------------------------------- 0.0/109.2 kB ? eta -:--:--
#    ------------------------------------- -- 102.4/109.2 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 109.2/109.2 kB 2.1 MB/s eta 0:00:00
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
#    ---------------------------------------- 0.0/68.1 kB ? eta -:--:--
#    ---------------------------------------- 68.1/68.1 kB 1.9 MB/s eta 0:00:00
# Downloading annotated_doc-0.0.3-py3-none-any.whl (5.5 kB)
# Downloading click-8.3.0-py3-none-any.whl (107 kB)
#    ---------------------------------------- 0.0/107.3 kB ? eta -:--:--
#    -------------------------------------- - 102.4/107.3 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 107.3/107.3 kB 2.1 MB/s eta 0:00:00
# Downloading starlette-0.49.3-py3-none-any.whl (74 kB)
#    ---------------------------------------- 0.0/74.3 kB ? eta -:--:--
#    -------------------------------------- - 71.7/74.3 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 74.3/74.3 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: click, annotated-doc, uvicorn, starlette, fastapi, langserve
# Successfully installed annotated-doc-0.0.3 click-8.3.0 fastapi-0.121.0 langserve-0.3.3 starlette-0.49.3 uvicorn-0.38.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
